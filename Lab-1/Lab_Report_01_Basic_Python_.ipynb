# %% [markdown]
# # <font color="darkblue" size="6"><b>Basic Python (With Explanation)</b></font>
#
# ### <font color="green">Objective:</font>
#
# To learn basic Python concepts such as variables, arithmetic operations, loops, and functions.

# %% [markdown]
# # <font color="red">Program</font>

# %%
num1 = 12
num2 = 8

product = num1 * num2
print("Product:", product)

for number in range(1, 6):
    print("Count:", number)

def cube(n):
    return n ** 3

print("Cube of 3:", cube(3))
# Out:
# Product: 96
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5
# Cube of 3: 27

# %% [markdown]
# ## <font color="orange"><b>Result</b></font>
#
# The program was executed successfully in Google Colab. The experiment demonstrated the use of variables, arithmetic operations, loops, functions, and output display in Python.

# %% [markdown]
# ## <font color="brown"><b>Student Information</b></font>
#
# **Name:** <font color="blue">Marajul Islam</font>
#
# **Roll:** <font color="red">28</font>
#
# **Lab Report No.:** <font color="green">01</font>
